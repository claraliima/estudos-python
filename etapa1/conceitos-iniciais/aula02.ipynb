# %% [markdown]
# Questao1

# %%
num = input("Digite um número ")
print("O número é: {}" .format(num))
# Out:
# Digite um número 12
# O número é: 12

# %% [markdown]
# Questão2

# %%
n1 = float(input("Digite um número "))
n2 = float(input("Digite outro número "))
soma = n1+n2
print("A soma dos números são: {}" .format(soma))
# Out:
# Digite um número 2
# Digite outro número 2
# A soma dos números são: 4.0

# %% [markdown]
# Questao3

# %%
lado = float(input("Digite o valor do lado do quadrado: "))
area = lado**lado
dobro_area = area*2
print("O dobro da área do quadrado é {}" .format(dobro_area))
# Out:
# Digite o valor do lado do quadrado: 2
# O dobro da área do quadrado é 8.0

# %% [markdown]
# Questao4

# %%
nota1 = float(input("Digite a 1ª nota: "))
nota2 = float(input("Digite a 2ª nota: "))
nota3 = float(input("Digite a 3ª nota: "))
nota4 = float(input("Digite a 4ª nota: "))
media = (nota1 + nota2 + nota3 + nota4)/4
print("A média bimestral é igual {}" .format(media))
# Out:
# Digite a 1ª nota: 4
# Digite a 2ª nota: 4
# Digite a 3ª nota: 4
# Digite a 4ª nota: 4
# A média bimestral é igual 4.0

# %% [markdown]
# Questao5

# %%
temp_F =  float(input("Digite a temperatura em Fahrenheit: "))
temp_C= (5/9) * (temp_F-32)
print("A temepratura em Celsius é {}" .format(temp_C))
# Out:
# Digite a temperatura em Celsius: 2
# A temepratura em Fahrenheit é 35.6

# %% [markdown]
# Questao6

# %%
n1 = int(input("Digite um número inteiro "))
n2 = int(input("Digite outro número inteiro "))
real = float(input("Digite um número real "))
conta1 = (n1*2) * (n2/2)
conta2 = (n1*3) + real
conta3 = real**3
print("A conta1 é {}, a conta 2 é {} e a conta 3 é {}" .format(conta1, conta2, conta3))
# Out:
# Digite um número inteiro 1
# Digite outro número inteiro 1
# Digite um número real 1
# A conta1 é 1.0, a conta 2 é 4.0 e a conta 3 é 1.0

# %% [markdown]
# Questao7

# %%
idade = int(input("Digite sua idade "))
idade_10 = idade + 10
print("Sua idade daqui a 10 anos é {}" .format(idade_10))
# Out:
# Digite sua idade 12
# Sua idade daqui a 10 anos é 22

# %% [markdown]
# Questao8

# %%
horas = float(input("Digite a quantidade de horas: "))
valor = float(input("Digite o valor da hora: "))
salario = (horas*valor)*30
print("O sálario mensal total é igual {}" .format(salario))

# %% [markdown]
# Questao9

# %%
nome = str(input("Digite o seu nome: "))
sobrenome = str(input("Digite o seu sobrenome: "))
inteiro = nome + " " + sobrenome
print("O seu nome completo é {}" .format(inteiro))
# Out:
# Digite o seu nome: clara
# Digite o seu sobrenome: araujo
# O seu nome completo é clara araujo
